# %%
# Standard Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Custom Libraries
from Option_Portfolio import OptionPortfolio

# %% [markdown]
# # Stock Parameters

# %%
stocks ={
    'A':{'S0':100., 'mu':0.05, 'sigma':0.1},
    }
r = 0.05
T = 1
reps = 1000
steps = 100

# %% [markdown]
# # Long 1 stock

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_stock(stock='A',num=1, sense='long')
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: -0.321050242176
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price product  type strike   cost count  total cost
# 0     A          100.0   stock  long      -  100.0     1       100.0
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Short 1 stock

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_stock(stock='A',num=1, sense='short')
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: 0.397977176854
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price product   type strike   cost count  total cost
# 0     A          100.0   stock  short      - -100.0     1      -100.0
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Long 1 Call option

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_call(stock='A',num=1,K=105,sense='buy',op_type='american', exercise=1)
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: -0.0834481465411
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price               product type strike      cost count  \
# 0     A          100.0  american call option  buy    105  4.077649     1
#
#    total cost
# 0    4.077649
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Short 1 Call Option

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_call(stock='A',num=1,K=105,sense='sell',op_type='american', exercise=1)
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: 0.0606627280824
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price               product  type strike      cost count  \
# 0     A          100.0  american call option  sell    105 -4.232754     1
#
#    total cost
# 0   -4.232754
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Long 1 Put Option

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_put(stock='A',num=1,K=105,sense='buy',op_type='american', exercise=1)
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: -1.4775603107
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price              product type strike      cost count  \
# 0     A          100.0  american put option  buy    105  5.468218     1
#
#    total cost
# 0    5.468218
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Short 1 Put Option

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_put(stock='A',num=1,K=105,sense='sell',op_type='american', exercise=1)
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: 1.50740889934
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price              product  type strike    cost count  \
# 0     A          100.0  american put option  sell    105 -5.3535     1
#
#    total cost
# 0     -5.3535
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Covered Call

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_stock(stock='A',num=5)
portf.add_call(stock='A',num=5,K=105,sense='sell',op_type='american', exercise=1)
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: 0.26755306822
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price               product  type strike        cost count  \
# 0     A          100.0                 stock  long      -  100.000000     5
# 1     A          100.0  american call option  sell    105   -4.208754     5
#
#    total cost
# 0  500.000000
# 1  -21.043772
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Married Put

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_stock(stock='A',num=5)
portf.add_put(stock='A',num=5,K=105,sense='buy',op_type='american', exercise=1)
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: -4.49076138146
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price              product  type strike        cost count  \
# 0     A          100.0                stock  long      -  100.000000     5
# 1     A          100.0  american put option   buy    105    5.224135     5
#
#    total cost
# 0  500.000000
# 1   26.120673
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Bull Call Spread

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_call(stock='A',num=5,K=100,sense='buy',op_type='american', exercise=1)
portf.add_call(stock='A',num=5,K=120,sense='sell',op_type='american', exercise=1)
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: 0.157695664993
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price               product  type strike      cost count  \
# 0     A          100.0  american call option   buy    100  6.798084     5
# 1     A          100.0  american call option  sell    120 -0.535614     5
#
#    total cost
# 0   33.990421
# 1   -2.678071
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Bear Put Spread

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_put(stock='A',num=5,K=120,sense='buy',op_type='american', exercise=1)
portf.add_put(stock='A',num=5,K=100,sense='sell',op_type='american', exercise=1)
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: -24.021753362
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price              product  type strike       cost count  \
# 0     A          100.0  american put option   buy    120  20.000000     5
# 1     A          100.0  american put option  sell    100  -2.499945     5
#
#    total cost
# 0  100.000000
# 1  -12.499724
# -------------------------------------------------------------------------------------
