# %%
# Standard Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Custom Libraries
from Option_Portfolio import OptionPortfolio

# %% [markdown]
# # Stock Parameters

# %%
stocks ={
    'A':{'S0':100., 'mu':0.1, 'sigma':0.1},
    'B':{'S0':50., 'mu':0.05, 'sigma':0.2},
    'C':{'S0':20., 'mu':0.03, 'sigma':0.12},
    }
r = 0.05
T = 1
reps = 1000
steps = 100

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_stock(stock='A',num=1, sense='long')
portf.add_put(stock='A',num=5,K=120,sense='buy',op_type='european')
portf.add_put(stock='A',num=5,K=100,sense='sell',op_type='european')

portf.add_call(stock='B',num=5,K=50,sense='buy',op_type='american', exercise=0.5)
portf.add_call(stock='B',num=5,K=55,sense='sell',op_type='american', exercise=0.5)

portf.add_stock(stock='C',num=5, sense='short')

print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
# portf.stock_plot('A')
# Out:
# Average Net portfolio value: 5.88180344674
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price               product   type strike        cost count  \
# 0     A          100.0                 stock   long      -  100.000000     1
# 1     A          100.0   european put option    buy    120   10.430384     5
# 2     A          100.0   european put option   sell    100   -0.804364     5
# 3     B           50.0  american call option    buy     50    5.249298     5
# 4     B           50.0  american call option   sell     55   -3.065897     5
# 5     C           20.0                 stock  short      -  -20.000000     5
#
#    total cost
# 0  100.000000
# 1   52.151920
# 2   -4.021818
# 3   26.246491
# 4  -15.329486
# 5 -100.000000
# -------------------------------------------------------------------------------------

# %%
# Variability due to Stock A
portf.stock_plot('A')

# %%
# Variability due to Stock B
portf.stock_plot('B')

# %%
# Variability due to Stock C
portf.stock_plot('C')
