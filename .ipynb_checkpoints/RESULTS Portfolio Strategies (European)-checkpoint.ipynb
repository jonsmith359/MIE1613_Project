# %%
# Standard Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Custom Libraries
from Option_Portfolio import OptionPortfolio

# %% [markdown]
# # Stock Parameters

# %%
stocks ={
    'A':{'S0':100., 'mu':0.05, 'sigma':0.1},
    }
r = 0.05
T = 1
reps = 1000
steps = 100

# %% [markdown]
# # Long 1 stock

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_stock(stock='A',num=1, sense='long')
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: 0.321447273708
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price product  type strike   cost count  total cost
# 0     A          100.0   stock  long      -  100.0     1       100.0
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Short 1 stock

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_stock(stock='A',num=1, sense='short')
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: 0.0535200868228
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price product   type strike   cost count  total cost
# 0     A          100.0   stock  short      - -100.0     1      -100.0
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Long 1 Call option

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_call(stock='A',num=1,K=105,sense='buy',op_type='european', exercise=0.1)
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: 0.0
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price               product type strike      cost count  \
# 0     A          100.0  european call option  buy    105  4.221795     1
#
#    total cost
# 0    4.221795
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Short 1 Call Option

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_call(stock='A',num=1,K=105,sense='sell',op_type='european')
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: 9.94759830064e-17
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price               product  type strike      cost count  \
# 0     A          100.0  european call option  sell    105 -3.816844     1
#
#    total cost
# 0   -3.816844
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Long 1 Put Option

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_put(stock='A',num=1,K=105,sense='buy',op_type='european')
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: -5.68434188608e-17
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price              product type strike      cost count  \
# 0     A          100.0  european put option  buy    105  3.791504     1
#
#    total cost
# 0    3.791504
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Short 1 Put Option

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_put(stock='A',num=1,K=105,sense='sell',op_type='european')
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: 3.97903932026e-16
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price              product  type strike      cost count  \
# 0     A          100.0  european put option  sell    105 -3.909861     1
#
#    total cost
# 0   -3.909861
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Covered Call

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_stock(stock='A',num=5)
portf.add_call(stock='A',num=5,K=105,sense='sell',op_type='european')
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: -1.29243913756
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price               product  type strike       cost count  \
# 0     A          100.0                 stock  long      -  100.00000     5
# 1     A          100.0  european call option  sell    105   -3.83474     5
#
#    total cost
# 0  500.000000
# 1  -19.173699
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Married Put

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_stock(stock='A',num=5)
portf.add_put(stock='A',num=5,K=105,sense='buy',op_type='european')
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: 1.08254522771
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price              product  type strike       cost count  \
# 0     A          100.0                stock  long      -  100.00000     5
# 1     A          100.0  european put option   buy    105    3.84037     5
#
#    total cost
# 0  500.000000
# 1   19.201852
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Bull Call Spread

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_call(stock='A',num=5,K=100,sense='buy',op_type='european')
portf.add_call(stock='A',num=5,K=120,sense='sell',op_type='european')
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: 4.32009983342e-15
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price               product  type strike      cost count  \
# 0     A          100.0  european call option   buy    100  6.859914     5
# 1     A          100.0  european call option  sell    120 -0.522306     5
#
#    total cost
# 0   34.299569
# 1   -2.611528
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Bear Put Spread

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_put(stock='A',num=5,K=120,sense='buy',op_type='european')
portf.add_put(stock='A',num=5,K=100,sense='sell',op_type='european')
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: 1.5916157281e-15
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price              product  type strike       cost count  \
# 0     A          100.0  european put option   buy    120  14.129066     5
# 1     A          100.0  european put option  sell    100  -1.725657     5
#
#    total cost
# 0   70.645330
# 1   -8.628286
# -------------------------------------------------------------------------------------
