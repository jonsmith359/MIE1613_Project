# %%
# Standard Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Custom Libraries
from Option_Portfolio import OptionPortfolio

# %% [markdown]
# # Stock Parameters

# %%
stocks ={
    'A':{'S0':100., 'mu':0.05, 'sigma':0.1},
    'B':{'S0':50., 'mu':0.1, 'sigma':0.2},
#     'C':{'S0':20., 'mu':0.08, 'sigma':0.12},
#     'D':{'S0':80., 'mu':0.02, 'sigma':0.03},
#     'E':{'S0':120., 'mu':0.05, 'sigma':0.2},
    }
r = 0.05
T = 1
reps = 1000
steps = 100

# %% [markdown]
# # Long 1 stock

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps, sensitivity=True, delta=0.1, stock='A')
# Out:
# 0.1

# %%
portf.add_call(stock='A',num=5,K=100,sense='buy',op_type='european')
portf.add_call(stock='A',num=5,K=120,sense='sell',op_type='european')
# portf.add_stock(stock='A',num=1)
print portf.products
portf.stock_plot('A')
# Out:
#   stock  current price               product  type strike      cost count  \
# 0     A          100.0  european call option   buy    100  7.092549     5
# 1     A          100.0  european call option  sell    120 -0.462081     5
#
#    total cost
# 0   35.462743
# 1   -2.310405

# %%
a,b,c,d = portf.sensitivity_analysis()

# %%
a,b,c
# Out:
# (-3.9790393202565614e-15, 1.2235545909788925e-14, 1.6214585230045486e-13)

# %%
portf.hist_plot()

# %%
portf.sensitivity_hist_plot()

# %%
#(self, stocks, r, T, reps, steps):
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_stock(stock='A',num=1)
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print portf.products
portf.stock_plot('A', cumulative=False)
# Out:
# flag
# Average Net portfolio value: 0.0857863402533
#   stock  current price product  type strike   cost count  total cost
# 0     A          100.0   stock  long      -  100.0     1       100.0

# %%
a,b,c = portf.net_value()

# %%
b,c
# Out:
# (0.085786340253281551, 0.61874270156154976)

# %%
portf.hist_plot()

# %%
temp = portf.net_value()
temp[temp>0]
np.mean(temp[temp>0])
# Out:
# 0.085786340253281551

# %% [markdown]
# # Short 1 stock

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_stock(stock='A',num=1, sense='short')
print portf.products
portf.stock_plot('A')
# Out:
# flag
#   stock  current price product   type strike   cost count  total cost
# 0     A          100.0   stock  short      - -100.0     1      -100.0

# %% [markdown]
# # Long 1 Call option

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
# portf.add_call(stock='A',num=1,K=105,sense='buy',op_type='european')
portf.add_call(stock='A',num=1,K=105,sense='buy',op_type='european', exercise=0.1)
print portf.products
portf.stock_plot('A')
# Out:
# flag
#   stock  current price               product type strike      cost count  \
# 0     A          100.0  european call option  buy    105  4.080047     1
#
#    total cost
# 0    4.080047

# %% [markdown]
# # Short 1 Call Option

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_call(stock='A',num=1,K=105,sense='sell',op_type='european')
print portf.products
portf.stock_plot('A')
# Out:
# flag
#   stock  current price               product  type strike      cost count  \
# 0     A          100.0  european call option  sell    105 -4.103698     1
#
#    total cost
# 0   -4.103698

# %% [markdown]
# # Long 1 Put Option

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_put(stock='A',num=1,K=105,sense='buy',op_type='european')
print portf.products
portf.stock_plot('A')
# Out:
# flag
#   stock  current price              product type strike      cost count  \
# 0     A          100.0  european put option  buy    105  4.199624     1
#
#    total cost
# 0    4.199624

# %% [markdown]
# # Short 1 Put Option

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_put(stock='A',num=1,K=105,sense='sell',op_type='european')
print portf.products
portf.stock_plot('A')
# Out:
# flag
#   stock  current price              product  type strike      cost count  \
# 0     A          100.0  european put option  sell    105 -3.855536     1
#
#    total cost
# 0   -3.855536

# %%
portf.net
# Out:
# array([ -3.14523666e+00,   3.85553609e+00,   3.85553609e+00,
#         -3.53492007e+00,   3.85553609e+00,   3.85553609e+00,
#          3.85553609e+00,  -1.27199169e+01,   3.85553609e+00,
#          3.85553609e+00,  -5.82885040e-02,   3.85553609e+00,
#         -5.13436319e+00,   3.85553609e+00,   3.85553609e+00,
#          3.12716180e+00,   3.85553609e+00,   3.85553609e+00,
#         -7.81049725e+00,   3.85553609e+00,   3.85553609e+00,
#         -1.88000223e+00,  -1.88083852e+00,  -1.33066865e+01,
#          3.85553609e+00,  -6.71645463e+00,   9.39252199e-01,
#          3.85553609e+00,  -2.72839193e+00,  -7.74398453e+00,
#          3.85553609e+00,   3.85553609e+00,  -8.08689003e+00,
#          3.10474818e+00,   2.31593689e+00,  -3.80825402e+00,
#         -3.30997897e+00,   3.85553609e+00,   3.85553609e+00,
#          3.85553609e+00,  -9.48597492e+00,   3.85553609e+00,
#         -7.53613399e+00,   3.85553609e+00,   2.04672677e+00,
# ...

# %% [markdown]
# # Covered Call

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_stock(stock='A',num=5)
portf.add_call(stock='A',num=5,K=105,sense='sell',op_type='european')
print portf.products
portf.stock_plot('A')
# Out:
# flag
#   stock  current price               product  type strike        cost count  \
# 0     A          100.0                 stock  long      -  100.000000     5
# 1     A          100.0  european call option  sell    105   -3.921057     5
#
#    total cost
# 0  500.000000
# 1  -19.605284

# %% [markdown]
# # Married Put

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_stock(stock='A',num=5)
portf.add_put(stock='A',num=5,K=105,sense='buy',op_type='european')
print portf.products
portf.stock_plot('A')
# Out:
# flag
#   stock  current price              product  type strike        cost count  \
# 0     A          100.0                stock  long      -  100.000000     5
# 1     A          100.0  european put option   buy    105    3.905314     5
#
#    total cost
# 0  500.000000
# 1   19.526571

# %% [markdown]
# # Bull Call Spread

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_call(stock='A',num=5,K=100,sense='buy',op_type='european')
portf.add_call(stock='A',num=5,K=120,sense='sell',op_type='european')
print portf.products
portf.stock_plot('A')
# Out:
# flag
#   stock  current price               product  type strike      cost count  \
# 0     A          100.0  european call option   buy    100  6.670727     5
# 1     A          100.0  european call option  sell    120 -0.446742     5
#
#    total cost
# 0   33.353636
# 1   -2.233711

# %% [markdown]
# # Bear Put Spread

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_put(stock='A',num=5,K=120,sense='buy',op_type='european')
portf.add_put(stock='A',num=5,K=100,sense='sell',op_type='european')
print portf.products
portf.stock_plot('A')
# Out:
# flag
#   stock  current price              product  type strike       cost count  \
# 0     A          100.0  european put option   buy    120  14.770123     5
# 1     A          100.0  european put option  sell    100  -1.963530     5
#
#    total cost
# 0   73.850613
# 1   -9.817650

# %%
portf.products
# Out:
#   stock  current price              product  type strike       cost count  \
# 0     A          100.0  european put option   buy    120  14.770123     5
# 1     A          100.0  european put option  sell    100  -1.963530     5
#
#    total cost
# 0   73.850613
# 1   -9.817650
