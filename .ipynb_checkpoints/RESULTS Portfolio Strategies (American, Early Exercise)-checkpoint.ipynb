# %%
# Standard Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Custom Libraries
from Option_Portfolio import OptionPortfolio

# %% [markdown]
# # Stock Parameters

# %%
stocks ={
    'A':{'S0':100., 'mu':0.05, 'sigma':0.1},
    }
r = 0.05
T = 1
reps = 1000
steps = 100

# %% [markdown]
# # Long 1 stock

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_stock(stock='A',num=1, sense='long')
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: 0.196760415842
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price product  type strike   cost count  total cost
# 0     A          100.0   stock  long      -  100.0     1       100.0
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Short 1 stock

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_stock(stock='A',num=1, sense='short')
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: 0.109633949403
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price product   type strike   cost count  total cost
# 0     A          100.0   stock  short      - -100.0     1      -100.0
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Long 1 Call option

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_call(stock='A',num=1,K=105,sense='buy',op_type='american', exercise=0.5)
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: -2.40853805665
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price               product type strike      cost count  \
# 0     A          100.0  american call option  buy    105  4.137107     1
#
#    total cost
# 0    4.137107
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Short 1 Call Option

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_call(stock='A',num=1,K=105,sense='sell',op_type='american', exercise=0.5)
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: 2.27539133619
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price               product  type strike      cost count  \
# 0     A          100.0  american call option  sell    105 -4.082775     1
#
#    total cost
# 0   -4.082775
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Long 1 Put Option

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_put(stock='A',num=1,K=105,sense='buy',op_type='american', exercise=0.5)
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: -1.07410643674
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price              product type strike      cost count  \
# 0     A          100.0  american put option  buy    105  5.427854     1
#
#    total cost
# 0    5.427854
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Short 1 Put Option

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_put(stock='A',num=1,K=105,sense='sell',op_type='american', exercise=0.5)
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: 1.02563880426
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price              product  type strike      cost count  \
# 0     A          100.0  american put option  sell    105 -5.499079     1
#
#    total cost
# 0   -5.499079
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Covered Call

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_stock(stock='A',num=5)
portf.add_call(stock='A',num=5,K=105,sense='sell',op_type='american', exercise=0.5)
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: 12.6997868882
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price               product  type strike        cost count  \
# 0     A          100.0                 stock  long      -  100.000000     5
# 1     A          100.0  american call option  sell    105   -4.127383     5
#
#    total cost
# 0  500.000000
# 1  -20.636915
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Married Put

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_stock(stock='A',num=5)
portf.add_put(stock='A',num=5,K=105,sense='buy',op_type='american', exercise=0.5)
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: -5.55401305516
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price              product  type strike        cost count  \
# 0     A          100.0                stock  long      -  100.000000     5
# 1     A          100.0  american put option   buy    105    5.390667     5
#
#    total cost
# 0  500.000000
# 1   26.953333
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Bull Call Spread

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_call(stock='A',num=5,K=110,sense='buy',op_type='american', exercise=0.5)
portf.add_call(stock='A',num=5,K=120,sense='sell',op_type='american', exercise=0.5)
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: -5.41547411137
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price               product  type strike      cost count  \
# 0     A          100.0  american call option   buy    110  2.127016     5
# 1     A          100.0  american call option  sell    120 -0.484395     5
#
#    total cost
# 0   10.635079
# 1   -2.421973
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Bear Put Spread

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_put(stock='A',num=5,K=120,sense='buy',op_type='american', exercise=0.5)
portf.add_put(stock='A',num=5,K=110,sense='sell',op_type='american', exercise=0.5)
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: -4.49505795115
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price              product  type strike  cost count  \
# 0     A          100.0  american put option   buy    120  20.0     5
# 1     A          100.0  american put option  sell    110 -10.0     5
#
#    total cost
# 0       100.0
# 1       -50.0
# -------------------------------------------------------------------------------------
