# %%
# Standard Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Custom Libraries
from Option_Portfolio import OptionPortfolio

# %% [markdown]
# # Stock Parameters

# %%
stocks ={
    'A':{'S0':100., 'mu':0.05, 'sigma':0.1},
    }
r = 0.05
T = 1
reps = 1000
steps = 100

# %% [markdown]
# # Long 1 stock

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_stock(stock='A',num=1, sense='long')
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: -0.319795337237
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price product  type strike   cost count  total cost
# 0     A          100.0   stock  long      -  100.0     1       100.0
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Short 1 stock

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_stock(stock='A',num=1, sense='short')
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: 0.0768863666714
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price product   type strike   cost count  total cost
# 0     A          100.0   stock  short      - -100.0     1      -100.0
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Long 1 Call option

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_call(stock='A',num=1,K=105,sense='buy',op_type='asian', exercise=0.1)
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: 7.81597009336e-17
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price            product type strike      cost count  \
# 0     A          100.0  asian call option  buy    105  1.459716     1
#
#    total cost
# 0    1.459716
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Short 1 Call Option

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_call(stock='A',num=1,K=105,sense='sell',op_type='asian')
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: 6.39488462184e-17
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price            product  type strike      cost count  \
# 0     A          100.0  asian call option  sell    105 -1.365732     1
#
#    total cost
# 0   -1.365732
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Long 1 Put Option

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_put(stock='A',num=1,K=105,sense='buy',op_type='asian')
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: 3.48165940522e-16
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price           product type strike      cost count  \
# 0     A          100.0  asian put option  buy    105  3.684009     1
#
#    total cost
# 0    3.684009
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Short 1 Put Option

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_put(stock='A',num=1,K=105,sense='sell',op_type='asian')
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: -4.36983782492e-16
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price           product  type strike      cost count  \
# 0     A          100.0  asian put option  sell    105 -3.754275     1
#
#    total cost
# 0   -3.754275
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Covered Call

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_stock(stock='A',num=5)
portf.add_call(stock='A',num=5,K=105,sense='sell',op_type='asian')
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: 0.25753900294
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price            product  type strike        cost count  \
# 0     A          100.0              stock  long      -  100.000000     5
# 1     A          100.0  asian call option  sell    105   -1.236138     5
#
#    total cost
# 0  500.000000
# 1   -6.180691
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Married Put

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_stock(stock='A',num=5)
portf.add_put(stock='A',num=5,K=100,sense='buy',op_type='asian')
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: -1.06747456802
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price           product  type strike        cost count  \
# 0     A          100.0             stock  long      -  100.000000     5
# 1     A          100.0  asian put option   buy    100    1.166916     5
#
#    total cost
# 0  500.000000
# 1    5.834581
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Bull Call Spread

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_call(stock='A',num=5,K=100,sense='buy',op_type='asian')
portf.add_call(stock='A',num=5,K=110,sense='sell',op_type='asian')
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: -3.12638803734e-16
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price            product  type strike      cost count  \
# 0     A          100.0  asian call option   buy    100  3.883732     5
# 1     A          100.0  asian call option  sell    110 -0.353963     5
#
#    total cost
# 0   19.418661
# 1   -1.769816
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Bear Put Spread

# %%
portf = OptionPortfolio(stocks = stocks,r=r, T=T, reps=reps, steps=steps)
portf.add_put(stock='A',num=5,K=110,sense='buy',op_type='asian')
portf.add_put(stock='A',num=5,K=100,sense='sell',op_type='asian')
print 'Average Net portfolio value:', np.mean(portf.net_value()[0])
print 'List of Portfolio Products'.center(85,"-")
print portf.products
print '-'*85
portf.stock_plot('A', cumulative=True)
# Out:
# Average Net portfolio value: -3.90798504668e-15
# ------------------------------List of Portfolio Products-----------------------------
#   stock  current price           product  type strike      cost count  \
# 0     A          100.0  asian put option   buy    110  7.657142     5
# 1     A          100.0  asian put option  sell    100 -1.304192     5
#
#    total cost
# 0   38.285712
# 1   -6.520962
# -------------------------------------------------------------------------------------
